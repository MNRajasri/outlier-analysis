# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\Rajasri\Documents\DATA SCIENCE Naresh IT\Data files\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ## <center> Box plt </center>

# %% [markdown]
# __Method-1__

# %% [markdown]
# - using matplotlib

# %%
plt.boxplot(visa_df["no_of_employees"],vert=False)
plt.show()

# %% [markdown]
# __Method-2__

# %% [markdown]
# - using seaborn

# %%
sns.boxplot(visa_df["no_of_employees"],orient="h")
plt.show()

# %% [markdown]
# ## <center> Histogram vs Boxplot </center>

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1).hist(visa_df["no_of_employees"])
plt.title("Histogram")
plt.subplot(1,2,2).boxplot(visa_df["no_of_employees"],vert=False)
plt.title("Boxplot")
plt.show()

# %% [markdown]
# ## <center> No of outliers </center>

# %%
q1=np.percentile(visa_df["no_of_employees"],25)
q3=np.percentile(visa_df["no_of_employees"],75)

lb=q1-1.5*(q3-q1)
ub=q1+1.5*(q3-q1)

con1=visa_df["no_of_employees"]<lb
con2=visa_df["no_of_employees"]>ub

visa_df_outliers=visa_df[con1 | con2]
visa_df_outliers
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 2         EZYV03           Asia            Bachelor's                  N
# 6         EZYV07           Asia            Bachelor's                  N
# 8         EZYV09           Asia            Bachelor's                  N
# 12        EZYV13           Asia            Bachelor's                  Y
# ...          ...            ...                   ...                ...
# 25441  EZYV25442           Asia              Master's                  N
# 25443  EZYV25444         Africa            Bachelor's                  N
# 25455  EZYV25456  South America            Bachelor's                  N
# 25464  EZYV25465           Asia              Master's                  N
# 25471  EZYV25472           Asia           High School                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# ## <center> No of non outliers </center>

# %%
q1=np.percentile(visa_df["no_of_employees"],25)
q3=np.percentile(visa_df["no_of_employees"],75)

lb=q1-1.5*(q3-q1)
ub=q1+1.5*(q3-q1)

con1=visa_df["no_of_employees"]>lb
con2=visa_df["no_of_employees"]<ub

visa_df_nonoutliers=visa_df[con1 & con2]
visa_df_nonoutliers
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 1         EZYV02           Asia              Master's                  Y
# 3         EZYV04           Asia            Bachelor's                  N
# 4         EZYV05         Africa              Master's                  Y
# 5         EZYV06           Asia              Master's                  Y
# 7         EZYV08  North America            Bachelor's                  Y
# ...          ...            ...                   ...                ...
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# ## <center> Whole data vs Non-Outliers data </center>

# %%
plt.figure(figsize=(10,7))
plt.subplot(2,2,1).hist(visa_df["no_of_employees"])
plt.title("Histogram")
plt.subplot(2,2,2).boxplot(visa_df["no_of_employees"],vert=False)
plt.title("Boxplot")
plt.subplot(2,2,3).hist(visa_df_nonoutliers["no_of_employees"])
plt.title("Histogram")
plt.subplot(2,2,4).boxplot(visa_df_nonoutliers["no_of_employees"],vert=False)
plt.title("Boxplot")
plt.show()

# %% [markdown]
# ## <center> How to deal with outliers </center>

# %% [markdown]
# - replacing with median

# %%
l=[]

q1=np.percentile(visa_df["no_of_employees"],q=25)
q3=np.percentile(visa_df["no_of_employees"],q=75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr

mediann=round(np.median(visa_df["no_of_employees"]),2)
mediann

for i in visa_df["no_of_employees"].values:
    if i<lb or i>ub:
        l.append(mediann)
    else:
        l.append(i)

df1=visa_df.copy()
df1["no_of_employees"]=l
df1
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N           2109.0         2007
# ...

# %%
plt.boxplot(df1["no_of_employees"],vert=False)
plt.show()

# %% [markdown]
# ## <center> Whole data vs Data replaced with median </center>

# %%
plt.figure(figsize=(10,7))
plt.subplot(2,2,1).hist(visa_df["no_of_employees"])
plt.title("Histogram")
plt.subplot(2,2,2).boxplot(visa_df["no_of_employees"],vert=False)
plt.title("Boxplot")
plt.subplot(2,2,3).hist(df1["no_of_employees"])
plt.title("Histogram")
plt.subplot(2,2,4).boxplot(df1["no_of_employees"],vert=False)
plt.title("Boxplot")
plt.show()

# %% [markdown]
# ## <center> np.where() </center>

# %%
q1=np.percentile(visa_df["no_of_employees"],q=25)
q3=np.percentile(visa_df["no_of_employees"],q=75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr

mediann=round(np.median(visa_df["no_of_employees"]),2)

con1=visa_df["no_of_employees"]<lb
con2=visa_df["no_of_employees"]>ub
con=con1|con2
ll=np.where(con,mediann,visa_df["no_of_employees"])

df1=visa_df.copy()
df1["no_of_employees"]=l
df1
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N           2109.0         2007
# ...

# %%
con1=visa_df["no_of_employees"]<lb
con2=visa_df["no_of_employees"]>ub
con=con1|con2
con
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 25475    False
# 25476    False
# 25477    False
# 25478    False
# 25479    False
# Name: no_of_employees, Length: 25480, dtype: bool

# %%
plt.boxplot(df1["no_of_employees"],vert=False)
plt.show()
